# %% [markdown]
# ### Import Data and Requirements

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib as mpl

# %%
ForestGenus = pd.read_csv('C:/Users/ehub9/Desktop/GitHub/Google-DataAnalytics-Capstone/Data/Clean_Data/genusiceland_weather_cleaned.csv')

# %%
ForestSpecies = pd.read_csv('C:/Users/ehub9/Desktop/GitHub/Google-DataAnalytics-Capstone/Data/Clean_Data/speciesiceland_weather_cleaned.csv')

# %%
RomanianSubArctic = pd.read_csv ('C:/Users/ehub9/Desktop/GitHub/Google-DataAnalytics-Capstone/Data/Clean_Data/RomanianSubArcticRegionsDF_cleaned.csv')

# %%
Parcels = pd.read_csv ('C:/Users/ehub9/Desktop/GitHub/Google-DataAnalytics-Capstone/Data/Clean_Data/SubArtictTreesParcel_cleaned.csv')

# %%
TestPlot = pd.read_csv('C:/Users/ehub9/Desktop/GitHub/Google-DataAnalytics-Capstone/Data/Clean_Data/IcelandTestPlot_cleaned.csv')

# %% [markdown]
# ### Data

# %%
ForestGenus
# Out:
#         COUNTRY   Genus
# 0       Finland   Abies
# 1       Finland   Abies
# 2       Finland   Abies
# 3       Finland   Abies
# 4       Finland   Abies
# ...         ...     ...
# 115587   Sweden  Sorbus
# 115588   Sweden  Sorbus
# 115589   Sweden  Sorbus
# 115590   Sweden  Sorbus
# 115591   Sweden  Sorbus
#
# [115592 rows x 2 columns]

# %%
ForestSpecies
# Out:
#         COUNTRY            SPECIES  DBH-1  DBH-2  NFI  FF  BS  EEO
# 0       Finland    Alnus glutinosa      0      1    1   0   0    1
# 1       Finland    Alnus glutinosa      1      1    1   0   0    0
# 2       Finland    Alnus glutinosa      1      1    1   0   0    1
# 3       Finland    Alnus glutinosa      0      1    1   0   0    1
# 4       Finland    Alnus glutinosa      0      1    1   0   0    1
# ...         ...                ...    ...    ...  ...  ..  ..  ...
# 115870   Sweden  Sorbus intermedia      1      0    1   0   0    1
# 115871   Sweden  Sorbus intermedia      0      1    1   0   0    1
# 115872   Sweden  Sorbus intermedia      0      1    1   0   0    1
# 115873   Sweden  Sorbus intermedia      0      1    1   0   0    1
# 115874   Sweden  Sorbus intermedia      0      1    1   0   0    1
#
# [115875 rows x 8 columns]

# %%
RomanianSubArtict
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10724\2047104729.py in <module>
# ----> 1 RomanianSubArtict
#
# NameError: name 'RomanianSubArtict' is not defined

# %%
Parcels

# %%
TestPlot

# %% [markdown]
# ### Data Analysis

# %% [markdown]
# #### Forest Genera

# %%
Parcels
# Out:
#       Unnamed: 0 Parcel         Plot         Name   Genus Treatment  \
# 0              0    SCG  SCG_TN1_GA1   White Pine   Pinus      acre
# 1              2    SCG  SCG_TN1_GA1   White Pine   Pinus      acre
# 2              3    SCG  SCG_TN1_GA1   Red Spruce   Picea      acre
# 3              4    SCG  SCG_TN1_GA1   Red Spruce   Picea      acre
# 4              5    SCG  SCG_TN1_GA1  Black Birch  Betula      acre
# ...          ...    ...          ...          ...     ...       ...
# 1966        2678    WOL     WOL_na_6   White Pine   Pinus   quarter
# 1967        2679    WOL     WOL_na_6   Red Spruce   Picea   quarter
# 1968        2682    WOL     WOL_na_6   White Pine   Pinus   quarter
# 1969        2683    WOL     WOL_na_6   Red Spruce   Picea   quarter
# 1970        2684    WOL     WOL_na_6   Red Spruce   Picea   quarter
#
#       4yr_survival                    FAM
# 0                1  Population Enrichment
# 1                0  Population Enrichment
# ...

# %%
Parcels.Name.unique()
# Out:
# array(['White Pine', 'Red Spruce', 'Black Birch'], dtype=object)

# %%
Parcels.insert(3,'Genus',0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10724\1451786352.py in <module>
# ----> 1 Parcels.insert(3,'Genus',0)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    4441         if not allow_duplicates and column in self.columns:
#    4442             # Should this be a different kind of error??
# -> 4443             raise ValueError(f"cannot insert {column}, already exists")
#    4444         if not isinstance(loc, int):
#    4445             raise TypeError("loc must be int")
#
# ValueError: cannot insert Genus, already exists

# %%
newgenus = {
        'White Pine': 'Pinus',
        'Red Spruce': 'Picea',
        'Black Birch': 'Betula'}

# %%
 for i, row in Parcels.iterrows():
        name = row['Name']
        if name in newgenus:
            Parcels.at[i, 'Genus'] = newgenus[name]
        elif name == 'Eastern Hemlock':
            Parcels.drop(i, inplace=True)

# %%
Parcels
# Out:
#       Unnamed: 0 Parcel         Plot         Name   Genus Treatment  \
# 0              0    SCG  SCG_TN1_GA1   White Pine   Pinus      acre
# 1              2    SCG  SCG_TN1_GA1   White Pine   Pinus      acre
# 2              3    SCG  SCG_TN1_GA1   Red Spruce   Picea      acre
# 3              4    SCG  SCG_TN1_GA1   Red Spruce   Picea      acre
# 4              5    SCG  SCG_TN1_GA1  Black Birch  Betula      acre
# ...          ...    ...          ...          ...     ...       ...
# 1966        2678    WOL     WOL_na_6   White Pine   Pinus   quarter
# 1967        2679    WOL     WOL_na_6   Red Spruce   Picea   quarter
# 1968        2682    WOL     WOL_na_6   White Pine   Pinus   quarter
# 1969        2683    WOL     WOL_na_6   Red Spruce   Picea   quarter
# 1970        2684    WOL     WOL_na_6   Red Spruce   Picea   quarter
#
#       4yr_survival                    FAM
# 0                1  Population Enrichment
# 1                0  Population Enrichment
# ...

# %%
Parcels.to_csv('C:/Users/ehub9/Desktop/GitHub/Google-DataAnalytics-Capstone/Data/Clean_Data/SubArtictTreesParcel_cleaned.csv')

# %%
ParcelsSurvived = Parcels.drop(Parcels[Parcels['4yr_survival'] == 0].index)

# %%
Parcels
# Out:
#       Unnamed: 0 Parcel         Plot         Name   Genus Treatment  \
# 0              0    SCG  SCG_TN1_GA1   White Pine   Pinus      acre
# 1              2    SCG  SCG_TN1_GA1   White Pine   Pinus      acre
# 2              3    SCG  SCG_TN1_GA1   Red Spruce   Picea      acre
# 3              4    SCG  SCG_TN1_GA1   Red Spruce   Picea      acre
# 4              5    SCG  SCG_TN1_GA1  Black Birch  Betula      acre
# ...          ...    ...          ...          ...     ...       ...
# 1966        2678    WOL     WOL_na_6   White Pine   Pinus   quarter
# 1967        2679    WOL     WOL_na_6   Red Spruce   Picea   quarter
# 1968        2682    WOL     WOL_na_6   White Pine   Pinus   quarter
# 1969        2683    WOL     WOL_na_6   Red Spruce   Picea   quarter
# 1970        2684    WOL     WOL_na_6   Red Spruce   Picea   quarter
#
#       4yr_survival                    FAM
# 0                1  Population Enrichment
# 1                0  Population Enrichment
# ...

# %%
genus_counts = Parcels['Genus'].value_counts()
genus_percents = genus_counts / genus_counts.sum()
genus_percents_filtered = genus_percents[genus_percents > 0.03]
colors_palette = genus_percents_filtered.index.map(colors_dict.get)
plt.pie(genus_percents_filtered.values, labels=genus_percents_filtered.index, autopct='%1.1f%%', colors=colors_palette)
plt.title('Main Genus in Test Parcel')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10724\3457938417.py in <module>
#       2 genus_percents = genus_counts / genus_counts.sum()
#       3 genus_percents_filtered = genus_percents[genus_percents > 0.03]
# ----> 4 colors_palette = genus_percents_filtered.index.map(colors_dict.get)
#       5 plt.pie(genus_percents_filtered.values, labels=genus_percents_filtered.index, autopct='%1.1f%%', colors=colors_palette)
#       6 plt.title('Main Genus in Test Parcel')
#
# NameError: name 'colors_dict' is not defined

# %%
treesCOLOR = {
    'Abies': '#132a13',
    'Alnus': '#31572c',
    'Black Birch': '#4f772d',
    'Corylus': '#90a955',
    'Juniperus': '#ecf39e',
    'Larix': '#f9c80e',
    'Red Spruce': '#99582a',
    'White Pine': '#bb9457',
    'Populus': '#8D6E63',
    'Salix': '#3E2723',
    'Sorbus': '#FF9800'
}

# %%
genus_counts = Parcels['Name'].value_counts()
genus_percents = genus_counts / genus_counts.sum()
genus_percents_filtered = genus_percents[genus_percents > 0.03]
colors_palette = genus_percents_filtered.index.map(treesCOLOR.get)
plt.pie(genus_percents_filtered.values, labels=genus_percents_filtered.index, autopct='%1.1f%%', colors=colors_palette)
plt.title('Main Species in Test Parcel')
plt.show()

# %%
ForestGenus
# Out:
#         COUNTRY   Genus
# 0       Finland   Abies
# 1       Finland   Abies
# 2       Finland   Abies
# 3       Finland   Abies
# 4       Finland   Abies
# ...         ...     ...
# 115587   Sweden  Sorbus
# 115588   Sweden  Sorbus
# 115589   Sweden  Sorbus
# 115590   Sweden  Sorbus
# 115591   Sweden  Sorbus
#
# [115592 rows x 2 columns]

# %%
ForestGenus.COUNTRY.unique()
# Out:
# array(['Finland', 'Norway', 'Sweden'], dtype=object)

# %%
ForestGenus.Genus.unique()
# Out:
# array(['Abies', 'Alnus', 'Betula', 'Corylus', 'Juniperus', 'Larix',
#        'Picea', 'Pinus', 'Populus', 'Salix', 'Sorbus'], dtype=object)

# %%
colors_dict = {
    'Abies': '#132a13',
    'Alnus': '#31572c',
    'Betula': '#4f772d',
    'Corylus': '#90a955',
    'Juniperus': '#ecf39e',
    'Larix': '#f9c80e',
    'Picea': '#99582a',
    'Pinus': '#bb9457',
    'Populus': '#8D6E63',
    'Salix': '#3E2723',
    'Sorbus': '#FF9800'
}

# %%
genus = ForestGenus[ForestGenus['COUNTRY'] == 'Finland']
genus_counts = genus['Genus'].value_counts()
genus_percents = genus_counts / genus_counts.sum()
genus_percents_filtered = genus_percents[genus_percents > 0.03]
colors_palette = genus_percents_filtered.index.map(colors_dict.get)
plt.pie(genus_percents_filtered.values, labels=genus_percents_filtered.index, autopct='%1.1f%%', colors=colors_palette)
plt.title('Main Tree Genus in Finland')
plt.show()

# %%
genus = ForestGenus[ForestGenus['COUNTRY'] == 'Norway']
genus_counts = genus['Genus'].value_counts()
genus_percents = genus_counts / genus_counts.sum()
genus_percents_filtered = genus_percents[genus_percents > 0.03]
colors_palette = genus_percents_filtered.index.map(colors_dict.get)
plt.pie(genus_percents_filtered.values, labels=genus_percents_filtered.index, autopct='%1.1f%%', colors=colors_palette)
plt.title('Main Tree Genus in Norway')
plt.show()

# %%
genus = ForestGenus[ForestGenus['COUNTRY'] == 'Sweden']
genus_counts = genus['Genus'].value_counts()
genus_percents = genus_counts / genus_counts.sum()
genus_percents_filtered = genus_percents[genus_percents > 0.03]
colors_palette = genus_percents_filtered.index.map(colors_dict.get)
plt.pie(genus_percents_filtered.values, labels=genus_percents_filtered.index, autopct='%1.1f%%', colors=colors_palette)
plt.title('Main Tree Genus in Sweden')
plt.show()

# %%
genus_percents = ForestGenus.groupby(['COUNTRY', 'Genus']).size().div(ForestGenus.groupby('COUNTRY').size(), level=0).mul(100).reset_index(name='Percentage').loc[lambda x: x['Percentage'] > 3]

# %%
genuspercetage
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10724\3667412321.py in <module>
# ----> 1 genuspercetage
#
# NameError: name 'genuspercetage' is not defined

# %%
genus_percents = ForestGenus.groupby(['COUNTRY', 'Genus']).size().div(ForestGenus.groupby('COUNTRY').size(), level=0).mul(100).reset_index(name='Percentage').loc[lambda x: x['Percentage'] > 3]
genus_percents_pivot = genus_percents.set_index(['Genus', 'COUNTRY']).unstack('COUNTRY')
ax = sns.heatmap(genus_percents_pivot, cmap='Greens', annot=True, fmt='.1f', cbar_kws={'label': 'Percentage'})
ax.set_xlabel('Country')
ax.set_title('Percentage of Genus by Country')
plt.show()

# %% [markdown]
# #### Forest Species

# %%
ForestSpecies
# Out:
#         COUNTRY            SPECIES  DBH-1  DBH-2  NFI  FF  BS  EEO
# 0       Finland    Alnus glutinosa      0      1    1   0   0    1
# 1       Finland    Alnus glutinosa      1      1    1   0   0    0
# 2       Finland    Alnus glutinosa      1      1    1   0   0    1
# 3       Finland    Alnus glutinosa      0      1    1   0   0    1
# 4       Finland    Alnus glutinosa      0      1    1   0   0    1
# ...         ...                ...    ...    ...  ...  ..  ..  ...
# 115870   Sweden  Sorbus intermedia      1      0    1   0   0    1
# 115871   Sweden  Sorbus intermedia      0      1    1   0   0    1
# 115872   Sweden  Sorbus intermedia      0      1    1   0   0    1
# 115873   Sweden  Sorbus intermedia      0      1    1   0   0    1
# 115874   Sweden  Sorbus intermedia      0      1    1   0   0    1
#
# [115875 rows x 8 columns]

# %%
ForestSpecies.COUNTRY.unique()
# Out:
# array(['Finland', 'Norway', 'Sweden'], dtype=object)

# %%
ForestSpecies.SPECIES.unique()
# Out:
# array(['Alnus glutinosa', 'Alnus incana', 'Betula nana', 'Betula pendula',
#        'Betula pubescens', 'Corylus avellana', 'Juniperus communis',
#        'Larix sibirica', 'Picea abies', 'Pinus contorta',
#        'Pinus sylvestris', 'Populus tremula', 'Salix aurita',
#        'Salix caprea', 'Salix cinerea', 'Salix glauca', 'Salix hastata',
#        'Salix lanata', 'Salix lapponum', 'Salix myrsinifolia',
#        'Salix myrtilloides', 'Salix pentandra', 'Salix phylicifolia',
#        'Salix repens', 'Salix rosmarinifolia', 'Salix starkeana',
#        'Sorbus aucuparia', 'Sorbus intermedia'], dtype=object)

# %%
species_percents = ForestSpecies.groupby(['COUNTRY', 'SPECIES']).size().div(ForestGenus.groupby('COUNTRY').size(), level=0).mul(100).reset_index(name='Percentage').loc[lambda x: x['Percentage'] > 5]

# %%
species_percents
# Out:
#     COUNTRY           SPECIES  Percentage
# 3   Finland    Betula pendula   11.130615
# 4   Finland  Betula pubescens   23.162850
# 8   Finland       Picea abies   26.241123
# 10  Finland  Pinus sylvestris   33.616852
# 30   Norway  Betula pubescens   33.469990
# 32   Norway       Picea abies   25.139390
# 34   Norway  Pinus sylvestris   21.695638
# 37   Norway  Sorbus aucuparia    7.457363
# 41   Sweden  Betula pubescens    7.432977
# 43   Sweden       Picea abies   29.626774
# 45   Sweden  Pinus sylvestris   29.865078

# %%
species_percents.SPECIES.unique()
# Out:
# array(['Betula pendula', 'Betula pubescens', 'Picea abies',
#        'Pinus sylvestris', 'Sorbus aucuparia'], dtype=object)

# %%
colors_dict2 ={
    'Betula pendula': '#6b8e23',   
    'Betula pubescens': '#8f9779', 
    'Picea abies': '#556b2f',      
    'Pinus sylvestris': '#8b4513', 
    'Sorbus aucuparia': '#228b22'  
    }

# %%
genus = ForestSpecies[ForestSpecies['COUNTRY'] == 'Finland']
genus_counts = genus['SPECIES'].value_counts()
genus_percents = genus_counts / genus_counts.sum()
genus_percents_filtered = genus_percents[genus_percents > 0.05]
colors_palette = genus_percents_filtered.index.map(colors_dict2.get)
plt.pie(genus_percents_filtered.values, labels=genus_percents_filtered.index, autopct='%1.1f%%', colors=colors_palette)
plt.title('Main Tree Species in Finland')
plt.show()

# %%
genus = ForestSpecies[ForestSpecies['COUNTRY'] == 'Norway']
genus_counts = genus['SPECIES'].value_counts()
genus_percents = genus_counts / genus_counts.sum()
genus_percents_filtered = genus_percents[genus_percents > 0.05]
colors_palette = genus_percents_filtered.index.map(colors_dict2.get)
plt.pie(genus_percents_filtered.values, labels=genus_percents_filtered.index, autopct='%1.1f%%', colors=colors_palette)
plt.title('Main Tree Species in Norway')
plt.show()

# %%
genus = ForestSpecies[ForestSpecies['COUNTRY'] == 'Sweden']
genus_counts = genus['SPECIES'].value_counts()
genus_percents = genus_counts / genus_counts.sum()
genus_percents_filtered = genus_percents[genus_percents > 0.05]
colors_palette = genus_percents_filtered.index.map(colors_dict2.get)
plt.pie(genus_percents_filtered.values, labels=genus_percents_filtered.index, autopct='%1.1f%%', colors=colors_palette)
plt.title('Main Tree Species in Sweden')
plt.show()

# %%
genus_percents = ForestSpecies.groupby(['COUNTRY', 'SPECIES']).size().div(ForestGenus.groupby('COUNTRY').size(), level=0).mul(100).reset_index(name='Percentage').loc[lambda x: x['Percentage'] > 3]
genus_percents_pivot = genus_percents.set_index(['SPECIES', 'COUNTRY']).unstack('COUNTRY')
ax = sns.heatmap(genus_percents_pivot, cmap='Greens', annot=True, fmt='.1f', cbar_kws={'label': 'Percentage'})
ax.set_xlabel('Country')
ax.set_title('Percentage of Species by Country')
plt.show()

# %%
ForestSpecies
# Out:
#         COUNTRY            SPECIES  DBH-1  DBH-2  NFI  FF  BS  EEO
# 0       Finland    Alnus glutinosa      0      1    1   0   0    1
# 1       Finland    Alnus glutinosa      1      1    1   0   0    0
# 2       Finland    Alnus glutinosa      1      1    1   0   0    1
# 3       Finland    Alnus glutinosa      0      1    1   0   0    1
# 4       Finland    Alnus glutinosa      0      1    1   0   0    1
# ...         ...                ...    ...    ...  ...  ..  ..  ...
# 115870   Sweden  Sorbus intermedia      1      0    1   0   0    1
# 115871   Sweden  Sorbus intermedia      0      1    1   0   0    1
# 115872   Sweden  Sorbus intermedia      0      1    1   0   0    1
# 115873   Sweden  Sorbus intermedia      0      1    1   0   0    1
# 115874   Sweden  Sorbus intermedia      0      1    1   0   0    1
#
# [115875 rows x 8 columns]

# %%
species_percents
# Out:
#     COUNTRY           SPECIES  Percentage
# 3   Finland    Betula pendula   11.130615
# 4   Finland  Betula pubescens   23.162850
# 8   Finland       Picea abies   26.241123
# 10  Finland  Pinus sylvestris   33.616852
# 30   Norway  Betula pubescens   33.469990
# 32   Norway       Picea abies   25.139390
# 34   Norway  Pinus sylvestris   21.695638
# 37   Norway  Sorbus aucuparia    7.457363
# 41   Sweden  Betula pubescens    7.432977
# 43   Sweden       Picea abies   29.626774
# 45   Sweden  Pinus sylvestris   29.865078

# %% [markdown]
# #### Finland Species

# %%
finnishspecieslist = ['Pinus sylvestris', 'Picea abies', 'Betula pubescens', 'Betula pendula']

# %%
finland_species = ForestSpecies[(ForestSpecies['COUNTRY'] == 'Finland') & (ForestSpecies['SPECIES'].isin(finnishspecieslist))]

# %%
finland_species
# Out:
#        COUNTRY           SPECIES  DBH-1  DBH-2  NFI  FF  BS  EEO
# 2411   Finland    Betula pendula      0      0    0   0   1    1
# 2412   Finland    Betula pendula      0      1    1   0   0    1
# 2413   Finland    Betula pendula      1      0    1   0   0    1
# 2414   Finland    Betula pendula      0      1    1   0   0    0
# 2415   Finland    Betula pendula      0      1    1   0   0    1
# ...        ...               ...    ...    ...  ...  ..  ..  ...
# 61660  Finland  Pinus sylvestris      1      1    1   0   0    1
# 61661  Finland  Pinus sylvestris      0      1    1   0   0    1
# 61662  Finland  Pinus sylvestris      1      1    1   0   0    1
# 61663  Finland  Pinus sylvestris      0      1    1   0   0    1
# 61664  Finland  Pinus sylvestris      0      1    1   0   0    1
#
# [59000 rows x 8 columns]

# %% [markdown]
# #### Finland Betula Pendula

# %%
finland_betulapendula = ForestSpecies[(ForestSpecies['COUNTRY'] == 'Finland') & (ForestSpecies['SPECIES'] == 'Betula pendula')]

# %%
finland_betulapendula
# Out:
#       COUNTRY         SPECIES  DBH-1  DBH-2  NFI  FF  BS  EEO
# 2411  Finland  Betula pendula      0      0    0   0   1    1
# 2412  Finland  Betula pendula      0      1    1   0   0    1
# 2413  Finland  Betula pendula      1      0    1   0   0    1
# 2414  Finland  Betula pendula      0      1    1   0   0    0
# 2415  Finland  Betula pendula      0      1    1   0   0    1
# ...       ...             ...    ...    ...  ...  ..  ..  ...
# 9381  Finland  Betula pendula      1      0    1   0   0    1
# 9382  Finland  Betula pendula      0      1    1   0   0    1
# 9383  Finland  Betula pendula      0      1    1   0   0    1
# 9384  Finland  Betula pendula      0      1    1   0   0    1
# 9385  Finland  Betula pendula      0      1    1   0   0    1
#
# [6975 rows x 8 columns]

# %%
finland_betulapendula['DBH-1'].describe()
# Out:
# count    6975.000000
# mean        0.367885
# std         0.482265
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
# Name: DBH-1, dtype: float64

# %%
finland_betulapendula['DBH-2'].describe()
# Out:
# count    6975.000000
# mean        0.749391
# std         0.433395
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: DBH-2, dtype: float64

# %%
finland_betulapendula = finland_betulapendula = ForestSpecies[(ForestSpecies['COUNTRY'] == 'Finland') & (ForestSpecies['SPECIES'] == 'Betula pendula')]
dbh1_mean = finland_betulapendula['DBH-1'].mean()
dbh2_mean = finland_betulapendula['DBH-2'].mean()
plt.bar(['DBH-1', 'DBH-2'], [dbh1_mean, dbh2_mean])
plt.title('Mean DBH for Betula pendula in Finland')
plt.xlabel('DBH class')
plt.ylabel('Mean DBH')
plt.show()

# %% [markdown]
# #### Finland Betula Pubescens

# %%
finland_Betulapubescens = ForestSpecies[(ForestSpecies['COUNTRY'] == 'Finland') & (ForestSpecies['SPECIES'] == 'Betula pubescens')]

# %%
finland_Betulapubescens
# Out:
#        COUNTRY           SPECIES  DBH-1  DBH-2  NFI  FF  BS  EEO
# 9386   Finland  Betula pubescens      1      0    1   0   0    1
# 9387   Finland  Betula pubescens      1      1    1   0   0    1
# 9388   Finland  Betula pubescens      0      1    1   0   0    1
# 9389   Finland  Betula pubescens      0      1    1   0   0    1
# 9390   Finland  Betula pubescens      1      1    1   0   0    1
# ...        ...               ...    ...    ...  ...  ..  ..  ...
# 23896  Finland  Betula pubescens      1      0    1   0   0    1
# 23897  Finland  Betula pubescens      0      0    0   1   0    1
# 23898  Finland  Betula pubescens      0      1    1   0   0    1
# 23899  Finland  Betula pubescens      1      1    1   0   0    1
# 23900  Finland  Betula pubescens      1      0    1   0   0    1
#
# [14515 rows x 8 columns]

# %%
finland_Betulapubescens['DBH-1'].describe()
# Out:
# count    14515.000000
# mean         0.693283
# std          0.461147
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000
# Name: DBH-1, dtype: float64

# %%
finland_Betulapubescens['DBH-2'].describe()
# Out:
# count    14515.000000
# mean         0.642852
# std          0.479175
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000
# Name: DBH-2, dtype: float64

# %%
finland_Betulapubescens = ForestSpecies[(ForestSpecies['COUNTRY'] == 'Finland') & (ForestSpecies['SPECIES'] == 'Betula pubescens')]
dbh1_mean = finland_Betulapubescens['DBH-1'].mean()
dbh2_mean = finland_Betulapubescens['DBH-2'].mean()
plt.bar(['DBH-1', 'DBH-2'], [dbh1_mean, dbh2_mean])
plt.title('Mean DBH for Betula pubescens in Finland')
plt.xlabel('DBH class')
plt.ylabel('Mean DBH')
plt.show()

# %% [markdown]
# #### Finland Picea Abies

# %%
finland_PA = ForestSpecies[(ForestSpecies['COUNTRY'] == 'Finland') & (ForestSpecies['SPECIES'] == 'Picea abies')]

# %%
finland_PA
# Out:
#        COUNTRY      SPECIES  DBH-1  DBH-2  NFI  FF  BS  EEO
# 24123  Finland  Picea abies      1      1    1   0   0    1
# 24124  Finland  Picea abies      1      0    1   0   0    1
# 24125  Finland  Picea abies      1      0    1   0   0    1
# 24126  Finland  Picea abies      0      1    1   0   0    1
# 24127  Finland  Picea abies      0      0    0   0   1    1
# ...        ...          ...    ...    ...  ...  ..  ..  ...
# 40562  Finland  Picea abies      1      1    1   0   0    1
# 40563  Finland  Picea abies      0      1    1   0   0    1
# 40564  Finland  Picea abies      1      1    1   0   0    1
# 40565  Finland  Picea abies      1      1    1   0   0    1
# 40566  Finland  Picea abies      0      0    0   1   0    1
#
# [16444 rows x 8 columns]

# %%
finland_PA['DBH-1'].describe()
# Out:
# count    16444.000000
# mean         0.627098
# std          0.483591
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000
# Name: DBH-1, dtype: float64

# %%
finland_PA['DBH-2'].describe()
# Out:
# count    16444.000000
# mean         0.795792
# std          0.403134
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000
# Name: DBH-2, dtype: float64

# %%
finland_PA = ForestSpecies[(ForestSpecies['COUNTRY'] == 'Finland') & (ForestSpecies['SPECIES'] == 'Picea abies')]
dbh1_mean = finland_PA['DBH-1'].mean()
dbh2_mean = finland_PA['DBH-2'].mean()
plt.bar(['DBH-1', 'DBH-2'], [dbh1_mean, dbh2_mean])
plt.title('Mean DBH for Betula pubescens in Finland')
plt.xlabel('DBH class')
plt.ylabel('Mean DBH')
plt.show()

# %% [markdown]
# #### Finland Pinus sylvestris

# %%
finland_PS = ForestSpecies[(ForestSpecies['COUNTRY'] == 'Finland') & (ForestSpecies['SPECIES'] == 'Pinus sylvestris')]

# %%
finland_PS
# Out:
#        COUNTRY           SPECIES  DBH-1  DBH-2  NFI  FF  BS  EEO
# 40599  Finland  Pinus sylvestris      0      1    1   0   0    1
# 40600  Finland  Pinus sylvestris      0      1    1   0   0    1
# 40601  Finland  Pinus sylvestris      1      0    1   0   0    1
# 40602  Finland  Pinus sylvestris      1      1    1   0   0    1
# 40603  Finland  Pinus sylvestris      0      1    1   0   0    1
# ...        ...               ...    ...    ...  ...  ..  ..  ...
# 61660  Finland  Pinus sylvestris      1      1    1   0   0    1
# 61661  Finland  Pinus sylvestris      0      1    1   0   0    1
# 61662  Finland  Pinus sylvestris      1      1    1   0   0    1
# 61663  Finland  Pinus sylvestris      0      1    1   0   0    1
# 61664  Finland  Pinus sylvestris      0      1    1   0   0    1
#
# [21066 rows x 8 columns]

# %%
finland_PS['DBH-1'].describe()
# Out:
# count    21066.000000
# mean         0.544242
# std          0.498051
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000
# Name: DBH-1, dtype: float64

# %%
finland_PS['DBH-2'].describe()
# Out:
# count    21066.000000
# mean         0.887402
# std          0.316109
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000
# Name: DBH-2, dtype: float64

# %%
finland_PS = ForestSpecies[(ForestSpecies['COUNTRY'] == 'Finland') & (ForestSpecies['SPECIES'] == 'Pinus sylvestris')]
dbh1_mean = finland_PS['DBH-1'].mean()
dbh2_mean = finland_PS['DBH-2'].mean()
plt.bar(['DBH-1', 'DBH-2'], [dbh1_mean, dbh2_mean])
plt.title('Mean DBH for Betula pubescens in Finland')
plt.xlabel('DBH class')
plt.ylabel('Mean DBH')
plt.show()

# %%
finnish_species_percentage = (ForestSpecies[ForestSpecies['COUNTRY'] == 'Finland']
                             .groupby('SPECIES')
                             .size()
                             .div(ForestSpecies[ForestSpecies['COUNTRY'] == 'Finland']
                                  .groupby('SPECIES')
                                  .size()
                                  .sum())
                             .mul(100)
                             .reset_index(name='Percentage')
                             .loc[lambda x: x['Percentage'] > 5])

# %%
finnish_species_percentage
# Out:
#              SPECIES  Percentage
# 3     Betula pendula   10.342680
# 4   Betula pubescens   21.523154
# 8        Picea abies   24.383517
# 10  Pinus sylvestris   31.237118

# %%
fin_species = ForestSpecies[ForestSpecies['COUNTRY'] == 'Finland']
species_counts = fin_species.groupby('SPECIES').size()
species_percentage = species_counts.div(species_counts.sum()).mul(100)
major_species = species_percentage[species_percentage >= 5].index.tolist()
fin_species = fin_species[fin_species['SPECIES'].isin(major_species)]
species_mean = fin_species.groupby('SPECIES').mean()
species_mean[['DBH-1', 'DBH-2']].plot(kind='bar', rot=0)
plt.xlabel('Species')
plt.ylabel('Mean DBH')
plt.title('Mean DBH of Main Tree Species in Finland')
plt.legend(frameon=False)
plt.show()

# %%
species_percents
# Out:
#     COUNTRY           SPECIES  Percentage
# 3   Finland    Betula pendula   11.130615
# 4   Finland  Betula pubescens   23.162850
# 8   Finland       Picea abies   26.241123
# 10  Finland  Pinus sylvestris   33.616852
# 30   Norway  Betula pubescens   33.469990
# 32   Norway       Picea abies   25.139390
# 34   Norway  Pinus sylvestris   21.695638
# 37   Norway  Sorbus aucuparia    7.457363
# 41   Sweden  Betula pubescens    7.432977
# 43   Sweden       Picea abies   29.626774
# 45   Sweden  Pinus sylvestris   29.865078

# %% [markdown]
# #### Norway Species

# %%
norway_species = species_percents[(species_percents['COUNTRY'] == 'Norway')]

# %%
norway_species
# Out:
#    COUNTRY           SPECIES  Percentage
# 30  Norway  Betula pubescens   33.469990
# 32  Norway       Picea abies   25.139390
# 34  Norway  Pinus sylvestris   21.695638
# 37  Norway  Sorbus aucuparia    7.457363

# %% [markdown]
# #### Betula pubescens

# %%
NOR_Betulapubescens = ForestSpecies[(ForestSpecies['COUNTRY'] == 'Norway') & (ForestSpecies['SPECIES'] == 'Betula pubescens')]

# %%
NOR_Betulapubescens
# Out:
#       COUNTRY           SPECIES  DBH-1  DBH-2  NFI  FF  BS  EEO
# 68861  Norway  Betula pubescens      1      0    1   0   0    1
# 68862  Norway  Betula pubescens      1      0    1   0   0    1
# 68863  Norway  Betula pubescens      1      1    1   0   0    1
# 68864  Norway  Betula pubescens      1      1    1   0   0    1
# 68865  Norway  Betula pubescens      1      1    1   0   0    1
# ...       ...               ...    ...    ...  ...  ..  ..  ...
# 77020  Norway  Betula pubescens      1      1    1   0   0    1
# 77021  Norway  Betula pubescens      1      1    1   0   0    1
# 77022  Norway  Betula pubescens      1      1    1   0   0    1
# 77023  Norway  Betula pubescens      1      1    1   0   0    1
# 77024  Norway  Betula pubescens      1      0    1   0   0    1
#
# [8164 rows x 8 columns]

# %%
NOR_Betulapubescens['DBH-1'].describe()
# Out:
# count    8164.000000
# mean        0.907643
# std         0.289547
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: DBH-1, dtype: float64

# %%
NOR_Betulapubescens['DBH-2'].describe()
# Out:
# count    8164.000000
# mean        0.626531
# std         0.483755
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: DBH-2, dtype: float64

# %%
dbh1_mean = NOR_Betulapubescens['DBH-1'].mean()
dbh2_mean = NOR_Betulapubescens['DBH-2'].mean()
plt.bar(['DBH-1', 'DBH-2'], [dbh1_mean, dbh2_mean])
plt.title('Mean DBH for Betula pubescens in Norway')
plt.xlabel('DBH class')
plt.ylabel('Mean DBH')
plt.show()

# %% [markdown]
# #### Picea abies

# %%
NOR_PA = ForestSpecies[(ForestSpecies['COUNTRY'] == 'Norway') & (ForestSpecies['SPECIES'] == 'Picea abies')]

# %%
NOR_PA
# Out:
#       COUNTRY      SPECIES  DBH-1  DBH-2  NFI  FF  BS  EEO
# 77206  Norway  Picea abies      0      1    1   0   0    1
# 77207  Norway  Picea abies      1      1    1   0   0    1
# 77208  Norway  Picea abies      1      0    1   0   0    1
# 77209  Norway  Picea abies      1      1    1   0   0    1
# 77210  Norway  Picea abies      1      1    1   0   0    1
# ...       ...          ...    ...    ...  ...  ..  ..  ...
# 83333  Norway  Picea abies      1      1    1   0   0    1
# 83334  Norway  Picea abies      1      1    1   0   0    1
# 83335  Norway  Picea abies      1      0    1   0   0    1
# 83336  Norway  Picea abies      1      1    1   0   0    1
# 83337  Norway  Picea abies      1      1    1   0   0    1
#
# [6132 rows x 8 columns]

# %%
NOR_PA['DBH-1'].describe()
# Out:
# count    6132.000000
# mean        0.880626
# std         0.324254
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: DBH-1, dtype: float64

# %%
NOR_PA['DBH-2'].describe()
# Out:
# count    6132.000000
# mean        0.798598
# std         0.401081
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: DBH-2, dtype: float64

# %%
dbh1_mean = NOR_PA['DBH-1'].mean()
dbh2_mean = NOR_PA['DBH-2'].mean()
plt.bar(['DBH-1', 'DBH-2'], [dbh1_mean, dbh2_mean])
plt.title('Mean DBH for Picea abies in Norway')
plt.xlabel('DBH class')
plt.ylabel('Mean DBH')
plt.show()

# %% [markdown]
# #### Pinus sylvestris

# %%
NOR_PS = ForestSpecies[(ForestSpecies['COUNTRY'] == 'Norway') & (ForestSpecies['SPECIES'] == 'Pinus sylvestris')]

# %%
NOR_PS
# Out:
#       COUNTRY           SPECIES  DBH-1  DBH-2  NFI  FF  BS  EEO
# 83366  Norway  Pinus sylvestris      0      1    1   0   0    1
# 83367  Norway  Pinus sylvestris      0      1    1   0   0    0
# 83368  Norway  Pinus sylvestris      1      1    1   0   0    1
# 83369  Norway  Pinus sylvestris      0      1    1   0   0    1
# 83370  Norway  Pinus sylvestris      1      1    1   0   0    1
# ...       ...               ...    ...    ...  ...  ..  ..  ...
# 88653  Norway  Pinus sylvestris      0      1    1   0   0    1
# 88654  Norway  Pinus sylvestris      1      1    1   0   0    1
# 88655  Norway  Pinus sylvestris      0      1    1   0   0    1
# 88656  Norway  Pinus sylvestris      1      1    1   0   0    1
# 88657  Norway  Pinus sylvestris      1      1    1   0   0    1
#
# [5292 rows x 8 columns]

# %%
NOR_PS['DBH-1'].describe()
# Out:
# count    5292.000000
# mean        0.570673
# std         0.495027
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: DBH-1, dtype: float64

# %%
NOR_PS['DBH-2'].describe()
# Out:
# count    5292.000000
# mean        0.901550
# std         0.297951
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: DBH-2, dtype: float64

# %%
dbh1_mean = NOR_PS['DBH-1'].mean()
dbh2_mean = NOR_PS['DBH-2'].mean()
plt.bar(['DBH-1', 'DBH-2'], [dbh1_mean, dbh2_mean])
plt.title('Mean DBH for Pinus sylvestris in Norway')
plt.xlabel('DBH class')
plt.ylabel('Mean DBH')
plt.show()

# %% [markdown]
# #### Sorbus aucuparia

# %%
NOR_SA = ForestSpecies[(ForestSpecies['COUNTRY'] == 'Norway') & (ForestSpecies['SPECIES'] == 'Sorbus aucuparia')]

# %%
NOR_SA
# Out:
#       COUNTRY           SPECIES  DBH-1  DBH-2  NFI  FF  BS  EEO
# 90201  Norway  Sorbus aucuparia      1      0    1   0   0    1
# 90202  Norway  Sorbus aucuparia      1      0    1   0   0    1
# 90203  Norway  Sorbus aucuparia      1      0    1   0   0    1
# 90204  Norway  Sorbus aucuparia      1      0    1   0   0    1
# 90205  Norway  Sorbus aucuparia      0      1    1   0   0    1
# ...       ...               ...    ...    ...  ...  ..  ..  ...
# 92015  Norway  Sorbus aucuparia      1      0    1   0   0    1
# 92016  Norway  Sorbus aucuparia      1      0    1   0   0    1
# 92017  Norway  Sorbus aucuparia      1      1    1   0   0    1
# 92018  Norway  Sorbus aucuparia      1      1    1   0   0    1
# 92019  Norway  Sorbus aucuparia      1      1    1   0   0    1
#
# [1819 rows x 8 columns]

# %%
NOR_SA['DBH-1'].describe()
# Out:
# count    1819.000000
# mean        0.873007
# std         0.333057
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: DBH-1, dtype: float64

# %%
NOR_SA['DBH-2'].describe()
# Out:
# count    1819.000000
# mean        0.369984
# std         0.482933
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
# Name: DBH-2, dtype: float64

# %%
dbh1_mean = NOR_SA['DBH-1'].mean()
dbh2_mean = NOR_SA['DBH-2'].mean()
plt.bar(['DBH-1', 'DBH-2'], [dbh1_mean, dbh2_mean])
plt.title('Mean DBH for Sorbus aucuparia in Norway')
plt.xlabel('DBH class')
plt.ylabel('Mean DBH')
plt.show()

# %%
nor_species = ForestSpecies[ForestSpecies['COUNTRY'] == 'Norway']
species_counts = nor_species.groupby('SPECIES').size()
species_percentage = species_counts.div(species_counts.sum()).mul(100)
major_species = species_percentage[species_percentage >= 5].index.tolist()
nor_species = nor_species[nor_species['SPECIES'].isin(major_species)]
species_mean = nor_species.groupby('SPECIES').mean()
species_mean[['DBH-1', 'DBH-2']].plot(kind='bar', rot=0)
plt.xlabel('Species')
plt.ylabel('Mean DBH')
plt.title('Mean DBH of Main Tree Species in Norway')
plt.legend(frameon=False)
plt.show()

# %% [markdown]
# #### Sweden Species

# %%
species_percents
# Out:
#     COUNTRY           SPECIES  Percentage
# 3   Finland    Betula pendula   11.130615
# 4   Finland  Betula pubescens   23.162850
# 8   Finland       Picea abies   26.241123
# 10  Finland  Pinus sylvestris   33.616852
# 30   Norway  Betula pubescens   33.469990
# 32   Norway       Picea abies   25.139390
# 34   Norway  Pinus sylvestris   21.695638
# 37   Norway  Sorbus aucuparia    7.457363
# 41   Sweden  Betula pubescens    7.432977
# 43   Sweden       Picea abies   29.626774
# 45   Sweden  Pinus sylvestris   29.865078

# %%
swe_species = species_percents[(species_percents['COUNTRY'] == 'Sweden')]

# %%
swe_species
# Out:
#    COUNTRY           SPECIES  Percentage
# 41  Sweden  Betula pubescens    7.432977
# 43  Sweden       Picea abies   29.626774
# 45  Sweden  Pinus sylvestris   29.865078

# %%
SWE_BP = ForestSpecies[(ForestSpecies['COUNTRY'] == 'Sweden') & (ForestSpecies['SPECIES'] == 'Betula pubescens')]

# %%
SWE_BP
# Out:
#       COUNTRY           SPECIES  DBH-1  DBH-2  NFI  FF  BS  EEO
# 93793  Sweden  Betula pubescens      1      1    1   0   0    1
# 93794  Sweden  Betula pubescens      0      0    0   1   0    1
# 93795  Sweden  Betula pubescens      1      1    1   0   0    1
# 93796  Sweden  Betula pubescens      0      1    1   0   0    1
# 93797  Sweden  Betula pubescens      1      0    1   0   0    1
# ...       ...               ...    ...    ...  ...  ..  ..  ...
# 95909  Sweden  Betula pubescens      0      1    1   0   0    1
# 95910  Sweden  Betula pubescens      0      1    1   0   0    1
# 95911  Sweden  Betula pubescens      0      0    0   1   0    1
# 95912  Sweden  Betula pubescens      0      1    1   0   0    1
# 95913  Sweden  Betula pubescens      0      1    1   0   0    1
#
# [2121 rows x 8 columns]

# %%
SWE_BP['DBH-1'].describe()
# Out:
# count    2121.000000
# mean        0.391325
# std         0.488162
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
# Name: DBH-1, dtype: float64

# %%
SWE_BP['DBH-2'].describe()
# Out:
# count    2121.000000
# mean        0.582273
# std         0.493301
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: DBH-2, dtype: float64

# %%
dbh1_mean = SWE_BP['DBH-1'].mean()
dbh2_mean = SWE_BP['DBH-2'].mean()
plt.bar(['DBH-1', 'DBH-2'], [dbh1_mean, dbh2_mean])
plt.title('Mean DBH for Betula pubescens in Sweden')
plt.xlabel('DBH class')
plt.ylabel('Mean DBH')
plt.show()

# %%
SWE_PA = ForestSpecies[(ForestSpecies['COUNTRY'] == 'Sweden') & (ForestSpecies['SPECIES'] == 'Picea abies')]

# %%
SWE_PA
# Out:
#        COUNTRY      SPECIES  DBH-1  DBH-2  NFI  FF  BS  EEO
# 95915   Sweden  Picea abies      1      1    1   0   0    1
# 95916   Sweden  Picea abies      1      1    1   0   0    1
# 95917   Sweden  Picea abies      1      1    1   0   0    1
# 95918   Sweden  Picea abies      1      1    1   0   0    1
# 95919   Sweden  Picea abies      1      1    1   0   0    1
# ...        ...          ...    ...    ...  ...  ..  ..  ...
# 104364  Sweden  Picea abies      0      1    1   0   0    1
# 104365  Sweden  Picea abies      0      1    1   0   0    1
# 104366  Sweden  Picea abies      1      1    1   0   0    1
# 104367  Sweden  Picea abies      1      1    1   0   0    1
# 104368  Sweden  Picea abies      1      0    1   0   0    1
#
# [8454 rows x 8 columns]

# %%
SWE_PA['DBH-1'].describe()
# Out:
# count    8454.000000
# mean        0.767211
# std         0.422634
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: DBH-1, dtype: float64

# %%
SWE_PA['DBH-2'].describe()
# Out:
# count    8454.000000
# mean        0.751005
# std         0.432456
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: DBH-2, dtype: float64

# %%
dbh1_mean = SWE_PA['DBH-1'].mean()
dbh2_mean = SWE_PA['DBH-2'].mean()
plt.bar(['DBH-1', 'DBH-2'], [dbh1_mean, dbh2_mean])
plt.title('Mean DBH for Picea abies in Sweden')
plt.xlabel('DBH class')
plt.ylabel('Mean DBH')
plt.show()

# %%
SWE_PS = ForestSpecies[(ForestSpecies['COUNTRY'] == 'Sweden') & (ForestSpecies['SPECIES'] == 'Pinus sylvestris')]

# %%
SWE_PS
# Out:
#        COUNTRY           SPECIES  DBH-1  DBH-2  NFI  FF  BS  EEO
# 104650  Sweden  Pinus sylvestris      1      1    1   0   0    1
# 104651  Sweden  Pinus sylvestris      1      0    1   0   0    1
# 104652  Sweden  Pinus sylvestris      0      1    1   0   0    0
# 104653  Sweden  Pinus sylvestris      1      0    1   0   0    1
# 104654  Sweden  Pinus sylvestris      1      1    1   0   0    1
# ...        ...               ...    ...    ...  ...  ..  ..  ...
# 113167  Sweden  Pinus sylvestris      1      1    1   1   0    1
# 113168  Sweden  Pinus sylvestris      1      1    1   0   0    1
# 113169  Sweden  Pinus sylvestris      1      1    1   0   0    1
# 113170  Sweden  Pinus sylvestris      0      0    0   1   0    1
# 113171  Sweden  Pinus sylvestris      0      1    1   0   0    1
#
# [8522 rows x 8 columns]

# %%
SWE_PS['DBH-1'].describe()
# Out:
# count    8522.000000
# mean        0.575452
# std         0.494303
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: DBH-1, dtype: float64

# %%
SWE_PS['DBH-2'].describe()
# Out:
# count    8522.000000
# mean        0.816944
# std         0.386735
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: DBH-2, dtype: float64

# %%
dbh1_mean = SWE_PS['DBH-1'].mean()
dbh2_mean = SWE_PS['DBH-2'].mean()
plt.bar(['DBH-1', 'DBH-2'], [dbh1_mean, dbh2_mean])
plt.title('Mean DBH for Pinus sylvestris in Sweden')
plt.xlabel('DBH class')
plt.ylabel('Mean DBH')
plt.show()

# %%
swe_species = ForestSpecies[ForestSpecies['COUNTRY'] == 'Sweden']
species_counts = swe_species.groupby('SPECIES').size()
species_percentage = species_counts.div(species_counts.sum()).mul(100)
major_species = species_percentage[species_percentage >= 5].index.tolist()
swe_species = swe_species[swe_species['SPECIES'].isin(major_species)]
species_mean = swe_species.groupby('SPECIES').mean()
species_mean[['DBH-1', 'DBH-2']].plot(kind='bar', rot=0)
plt.xlabel('Species')
plt.ylabel('Mean DBH')
plt.title('Mean DBH of Main Tree Species in Sweden')
plt.legend(frameon=False)
plt.show()

# %% [markdown]
# #### DBH Analysis

# %%
ForestSpecies
# Out:
#         COUNTRY            SPECIES  DBH-1  DBH-2  NFI  FF  BS  EEO
# 0       Finland    Alnus glutinosa      0      1    1   0   0    1
# 1       Finland    Alnus glutinosa      1      1    1   0   0    0
# 2       Finland    Alnus glutinosa      1      1    1   0   0    1
# 3       Finland    Alnus glutinosa      0      1    1   0   0    1
# 4       Finland    Alnus glutinosa      0      1    1   0   0    1
# ...         ...                ...    ...    ...  ...  ..  ..  ...
# 115870   Sweden  Sorbus intermedia      1      0    1   0   0    1
# 115871   Sweden  Sorbus intermedia      0      1    1   0   0    1
# 115872   Sweden  Sorbus intermedia      0      1    1   0   0    1
# 115873   Sweden  Sorbus intermedia      0      1    1   0   0    1
# 115874   Sweden  Sorbus intermedia      0      1    1   0   0    1
#
# [115875 rows x 8 columns]

# %%
import pandas as pd

def filter_species(df):
    species_percents = df.groupby(['COUNTRY', 'SPECIES']).size().div(df.groupby('COUNTRY').size(), level=0).mul(100).reset_index(name='Percentage')
    species_list = species_percents[species_percents['Percentage'] >= 5]['SPECIES'].tolist()
    return df[['COUNTRY', 'SPECIES', 'DBH-1', 'DBH-2', 'EEO']][df['SPECIES'].isin(species_list)]
dbh_df = filter_species(ForestSpecies)

# %%
dbh_df
# Out:
#         COUNTRY           SPECIES  DBH-1  DBH-2  EEO
# 2411    Finland    Betula pendula      0      0    1
# 2412    Finland    Betula pendula      0      1    1
# 2413    Finland    Betula pendula      1      0    1
# 2414    Finland    Betula pendula      0      1    0
# 2415    Finland    Betula pendula      0      1    1
# ...         ...               ...    ...    ...  ...
# 115809   Sweden  Sorbus aucuparia      1      0    1
# 115810   Sweden  Sorbus aucuparia      1      0    1
# 115811   Sweden  Sorbus aucuparia      1      0    1
# 115812   Sweden  Sorbus aucuparia      1      1    1
# 115813   Sweden  Sorbus aucuparia      0      0    1
#
# [103233 rows x 5 columns]

# %%
Parcels
# Out:
#       Unnamed: 0 Parcel         Plot         Name   Genus Treatment  \
# 0              0    SCG  SCG_TN1_GA1   White Pine   Pinus      acre
# 1              2    SCG  SCG_TN1_GA1   White Pine   Pinus      acre
# 2              3    SCG  SCG_TN1_GA1   Red Spruce   Picea      acre
# 3              4    SCG  SCG_TN1_GA1   Red Spruce   Picea      acre
# 4              5    SCG  SCG_TN1_GA1  Black Birch  Betula      acre
# ...          ...    ...          ...          ...     ...       ...
# 1966        2678    WOL     WOL_na_6   White Pine   Pinus   quarter
# 1967        2679    WOL     WOL_na_6   Red Spruce   Picea   quarter
# 1968        2682    WOL     WOL_na_6   White Pine   Pinus   quarter
# 1969        2683    WOL     WOL_na_6   Red Spruce   Picea   quarter
# 1970        2684    WOL     WOL_na_6   Red Spruce   Picea   quarter
#
#       4yr_survival                    FAM
# 0                1  Population Enrichment
# 1                0  Population Enrichment
# ...

# %%
ParcelsSurvived
# Out:
#       Unnamed: 0 Parcel         Plot         Name   Genus Treatment  \
# 0              0    SCG  SCG_TN1_GA1   White Pine   Pinus      acre
# 2              3    SCG  SCG_TN1_GA1   Red Spruce   Picea      acre
# 3              4    SCG  SCG_TN1_GA1   Red Spruce   Picea      acre
# 6              8    SCG  SCG_TN1_GA1  Black Birch  Betula      acre
# 7              9    SCG  SCG_TN1_GA1   Red Spruce   Picea      acre
# ...          ...    ...          ...          ...     ...       ...
# 1965        2677    WOL     WOL_na_6   White Pine   Pinus   quarter
# 1966        2678    WOL     WOL_na_6   White Pine   Pinus   quarter
# 1968        2682    WOL     WOL_na_6   White Pine   Pinus   quarter
# 1969        2683    WOL     WOL_na_6   Red Spruce   Picea   quarter
# 1970        2684    WOL     WOL_na_6   Red Spruce   Picea   quarter
#
#       4yr_survival                    FAM
# 0                1  Population Enrichment
# 2                1  Population Enrichment
# ...

# %%
counts = Parcels['4yr_survival'].value_counts()
ParcelsSurvivedpercentages = counts / len(Parcels) * 100

# %%
ParcelsSurvivedpercentages
# Out:
# 1    59.969559
# 0    40.030441
# Name: 4yr_survival, dtype: float64

# %%
Parcels['FAM'].value_counts()
# Out:
# Population Enrichment    1405
# Range Expansion           566
# Name: FAM, dtype: int64

# %%
ParcelsSurvived[(ParcelsSurvived['FAM'].isin(['Range Expansion', 'Population Enrichment']))].groupby(['Name', 'FAM']).size()
# Out:
# Name         FAM
# Black Birch  Range Expansion          225
# Red Spruce   Population Enrichment    526
# White Pine   Population Enrichment    431
# dtype: int64

# %%
TestPlot
# Out:
#      Unnamed: 0  Subplot  TreeID TreeID_Onsite Stand  Con_DBH        Con_X  \
# 0             1        2       1          2002    Bp     27.0 -70070.25366
# 1             2        2       2          2003    Bp     28.5 -70068.97007
# 2             3        2       3          2004    Bp     20.5 -70067.56394
# 3             4        2       4          2005    Bp     31.4 -70066.10057
# 4             5        2       5          2006    Bp     16.1 -70065.12875
# ..          ...      ...     ...           ...   ...      ...          ...
# 667         668       25      35           795    Nf      6.3 -69967.72500
# 668         669       25      36           796    Nf     42.8 -69967.13173
# 669         670       25      37           798    Nf     21.1 -69966.48547
# 670         671       25      38           797    Nf      7.8 -69967.01790
# 671         672       25      39           794    Nf     20.8 -69967.76670
#
# ...

# %%
diametersdib = pd.concat([TestPlot['Con_DBH'], TestPlot['Pad_DBH'], TestPlot['Pho_DBH']])

# %%
diametersdib
# Out:
# 0      27.0
# 1      28.5
# 2      20.5
# 3      31.4
# 4      16.1
#        ...
# 667     7.3
# 668    43.6
# 669    19.1
# 670    12.0
# 671    20.5
# Length: 2016, dtype: float64

# %%
plt.hist(diametersdib, bins=30)
plt.xlabel('Diameter (cm)')
plt.ylabel('Frequency')
plt.show()

# %%
mostgrown = TestPlot.nlargest(100, 'Pho_DBH')

# %%
mostgrown[['TreeID', 'Subplot', 'TreeID_Onsite', 'Pho_DBH']]
# Out:
#      TreeID  Subplot TreeID_Onsite  Pho_DBH
# 567      10       22           735     73.1
# 569      12       22           736     68.8
# 128      24        5           713     66.8
# 358      22       15           779     66.3
# 557      30       21           734     64.9
# ..      ...      ...           ...      ...
# 554      27       21         732_1     34.3
# 642      10       25           826     34.3
# 81        2        4           689     34.2
# 450      14       18           643     34.2
# 416      18       17           698     33.9
#
# [100 rows x 4 columns]

# %%
mostgrown.Subplot.value_counts()
# Out:
# 18    13
# 21     9
# 10     9
# 3      7
# 6      7
# 17     7
# 16     6
# 25     5
# 5      4
# 11     4
# 22     4
# 23     4
# 4      3
# 2      3
# 24     3
# 12     3
# 7      2
# 13     2
# 15     2
# 20     2
# 8      1
# Name: Subplot, dtype: int64

# %%
TestPlot.groupby('Subplot').nunique()['TreeID'].sort_values(ascending=False)
# Out:
# Subplot
# 3     56
# 9     43
# 5     42
# 19    40
# 25    39
# 23    39
# 17    38
# 18    37
# 12    32
# 15    31
# 16    31
# 21    30
# 10    29
# 4     25
# 2     24
# 24    21
# 6     19
# 8     18
# 11    17
# 13    17
# 7     15
# 22    15
# 20    14
# Name: TreeID, dtype: int64
